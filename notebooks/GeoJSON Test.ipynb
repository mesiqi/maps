# %%
# basic stuff
import os
import pandas as pd
import numpy as np
from random import randint, uniform
from datetime import datetime
from zipfile import ZipFile

# geo stuff
import geopandas as gpd
from shapely.geometry import Point
# from ipyleaflet import (Map,
#     Marker,
#     TileLayer, ImageOverlay,
#     Polyline, Polygon, Rectangle, Circle, CircleMarker,
#     GeoJSON,
#     DrawControl
# )

# plotting stuff
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('bmh')
plt.rcParams['figure.figsize'] = (10.0, 10.0)

# widget stuff
from ipywidgets import interact, HTML, FloatSlider
from IPython.display import clear_output, display

# turn warnings off
import warnings
warnings.filterwarnings('ignore')

# %%
gdf = gpd.GeoDataFrame.from_file('/users/b149899/projects/dataparcel/geodata/world/ne_50m_admin_1.geojson')

# %%
gdf
# Out:
#             featurecla  scalerank adm1_code  \
# 0   Admin-1 scale rank        2.0  AUS-2651
# 1   Admin-1 scale rank        2.0  AUS-2650
# 2   Admin-1 scale rank        2.0  AUS-2655
# 3   Admin-1 scale rank        2.0  AUS-2657
# 4   Admin-1 scale rank        2.0  AUS-2660
# 5   Admin-1 scale rank        2.0  AUS-2656
# 6   Admin-1 scale rank        2.0  AUS-2653
# 7   Admin-1 scale rank        2.0  AUS-1932
# 8   Admin-1 scale rank        2.0  AUS-2654
# 9   Admin-1 scale rank        2.0   BRA-576
# 10  Admin-1 scale rank        2.0   BRA-595
# 11  Admin-1 scale rank        2.0   BRA-670
# 12  Admin-1 scale rank        2.0   BRA-592
# 13  Admin-1 scale rank        2.0   BRA-594
# 14  Admin-1 scale rank        2.0   BRA-600
# 15  Admin-1 scale rank        2.0   BRA-681
# 16  Admin-1 scale rank        2.0   BRA-602
# 17  Admin-1 scale rank        2.0   BRA-613
# 18  Admin-1 scale rank        2.0   BRA-599
# 19  Admin-1 scale rank        2.0  BRA-1294
# ...

# %%
gdf.plot()

# %%
gdf = gpd.GeoDataFrame.from_file('/users/b149899/projects/dataparcel/geodata/norway/fylker.geojson')

# %%
gdf.plot()

# %%
gdf = gpd.GeoDataFrame.from_file('/users/b149899/projects/dataparcel/geodata/norway/no-all-svalbard-and-jan-mayen.geojson')
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: /users/b149899/projects/dataparcel/geodata/norway/no-all-svalbard-and-jan-mayen.geojson: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-9-f83529927e1b> in <module>
# ----> 1 gdf = gpd.GeoDataFrame.from_file('/users/b149899/projects/dataparcel/geodata/norway/no-all-svalbard-and-jan-mayen.geojson')
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/geopandas/geodataframe.py in from_file(cls, filename, **kwargs)
#     179         >>> df = geopandas.GeoDataFrame.from_file('nybb.shp')
#     180         """
# ...

# %%
gdf.plot()

# %%
gdf = gpd.GeoDataFrame.from_file('/users/b149899/projects/dataparcel/geodata/norway/fylker.geojson')

# %%
gdf.plot()

# %%
# !geo2topo '/users/b149899/projects/dataparcel/geodata/norway/fylker.geojson' > '/users/b149899/projects/dataparcel/geodata/norway/fylker.topojson'

# %%
# !toposimplify -p 1 -f \
    < '/users/b149899/projects/dataparcel/geodata/norway/fylker.topojson' \
    > '/users/b149899/projects/dataparcel/geodata/norway/fylker-simple.topojson'

# %%
# !topo2geo '/users/b149899/projects/dataparcel/geodata/norway/fylker-simple.topojson' > '/users/b149899/projects/dataparcel/geodata/norway/fylker-simple.geojson'

# %%
gdf = gpd.GeoDataFrame.from_file('/users/b149899/projects/dataparcel/geodata/norway/fylker-simple.geojson')

# %%
gdf.plot()

# %%
gdf
